# %%
import numpy as np
import matplotlib.pyplot as plt
# from scipy.stats import uniform
# import random as rand
# from scipy.stats import norm

# %%
def cholesky_fbm(H, n):
    sigma = np.zeros((n, n))
    for s in range(1, n+1):
        for t in range(s, n+1):
            gamma = (s**(2*H) + t**(2*H) - (t-s)**(2*H)) / 2
            sigma[s-1][t-1] = gamma
            sigma[t-1][s-1] = gamma
    L = np.linalg.cholesky(sigma)
    Z = np.random.normal(0, 1, n)
    fbm = np.dot(L, Z.reshape(-1,1))
    return np.transpose(fbm)[0]

# %%
H = [0.3, 0.5, 0.7]
n = 2**10
N = 5

# %%
all_fbm = []
t = list(range(n))
fig, axs = plt.subplots(1, 3, figsize = (15, 4))
for i, h in enumerate(H):
    fbm = [cholesky_fbm(H, n) for _ in range(N)]
    plt.plot(t, np.transpose(fbm))
    plt.axhline(0, color = 'black')
    axs[i].plot(t, np.transpose(fbm))
    axs[i].set_title(f'A plot for H = {h}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 5
#       3 fig, axs = plt.subplots(1, 3, figsize = (15, 4))
#       4 for i, h in enumerate(H):
# ----> 5     fbm = [cholesky_fbm(H, n) for _ in range(N)]
#       6     plt.plot(t, np.transpose(fbm))
#       7     plt.axhline(0, color = 'black')
#
# Cell In[82], line 5, in <listcomp>(.0)
#       3 fig, axs = plt.subplots(1, 3, figsize = (15, 4))
#       4 for i, h in enumerate(H):
# ----> 5     fbm = [cholesky_fbm(H, n) for _ in range(N)]
#       6     plt.plot(t, np.transpose(fbm))
#       7     plt.axhline(0, color = 'black')
#
# Cell In[77], line 5, in cholesky_fbm(H, n)
#       3 for s in range(1, n+1):
#       4     for t in range(s, n+1):
# ----> 5         gamma = (s**(2*H) + t**(2*H) - (t-s)**(2*H)) / 2
#       6         sigma[s-1][t-1] = gamma
#       7         sigma[t-1][s-1] = gamma
#
# TypeError: unsupported operand type(s) for ** or pow(): 'int' and 'list'

# %%
t = list(range(n))
plt.plot(t, np.transpose(fbm))
plt.show()
